# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Data

# %%
df1 = pd.read_csv('May.csv', delimiter=';', encoding='cp1252' , header=0, skiprows=[1] , index_col=[0])
df2 = pd.read_csv('June.csv', delimiter=';', encoding='cp1252' , header=0, skiprows=[1] , index_col=[0])
df3 = pd.read_csv('July.csv', delimiter=';', encoding='cp1252', header=0, skiprows=[1] , index_col=[0])
df4 = pd.read_csv('August.csv', delimiter=';', encoding='cp1252', header=0, skiprows=[1] , index_col=[0])
df5 = pd.read_csv('September.csv', delimiter=';', encoding='cp1252', header=0, skiprows=[1] , index_col=[0])
df6 = pd.read_csv('October.csv', delimiter=';', encoding='cp1252', header=0, skiprows=[1] , index_col=[0])

# %%
dataframes = [df1, df2, df3, df4, df5, df6]

# Concatenate the DataFrames along the rows (axis=0)
df = pd.concat(dataframes, axis=0, ignore_index=True)

df = df.drop(columns='_id')

# %%
df.replace("ERROR", np.nan, inplace=True)

# %% [markdown]
# # Mill Normal Operation

# %%
df['mill_motor_pwr_kw_pv'].value_counts()
df['mill_motor_pwr_kw_pv'].dtype
df[df['mill_motor_pwr_kw_pv'] == 'ERROR']['mill_operation'].value_counts()
df['mill_motor_pwr_kw_pv'].replace({'ERROR' : 0}, inplace = True)
df['mill_motor_pwr_kw_pv'] = df['mill_motor_pwr_kw_pv'].astype(float)
sns.distplot(df['mill_motor_pwr_kw_pv'])
# Out:
# <AxesSubplot: xlabel='mill_motor_pwr_kw_pv', ylabel='Density'>

# %%
df = df[(df['mill_motor_pwr_kw_pv'] > 250) & (df['mill_motor_pwr_kw_pv'] < 1750)]
df = df.reset_index(drop=True)

sns.distplot(df['mill_motor_pwr_kw_pv'])
# Out:
# <AxesSubplot: xlabel='mill_motor_pwr_kw_pv', ylabel='Density'>

# %%
(df['mill_motor_pwr_kw_pv'].dtype , df['mill_motor_pwr_kw_pv'].isna().sum())
# Out:
# (dtype('float64'), 0)

# %% [markdown]
# # Datetime Format

# %%
# Import the 're' module for working with regular expressions
import re

# Retrieve the 'date' values from 'august' DataFrame where the value does not start with '2019'
date1 = df[~df['date'].str.startswith('2019')]['date']

# Retrieve the 'date' values from 'august' DataFrame where the value starts with '2019'
date2 = df[df['date'].str.startswith('2019')]['date']

# Randomly sample 20 values from 'date1'
date1.sample(20)
# Out:
# 56315       1/7/2019 7:42
# 25558      24/5/2019 6:30
# 14066     17/5/2019 14:20
# 135294    10/8/2019 12:48
# 102891     29/7/2019 3:30
# 39231      4/6/2019 16:58
# 120493     4/8/2019 13:44
# 141992    12/8/2019 22:01
# 219197    14/9/2019 14:20
# 97329      27/7/2019 4:45
# 123582     5/8/2019 15:52
# 129888     7/8/2019 21:54
# 18513      19/5/2019 9:27
# 211415    11/9/2019 19:04
# 88183     18/7/2019 19:07
# 229141     18/9/2019 2:52
# 141853    12/8/2019 20:51
# 115973     2/8/2019 23:40
# 133781     10/8/2019 0:06
# 113453      2/8/2019 1:11
# Name: date, dtype: object

# %%
# Modify the 'date1' values by adding a leading '0' to the hour component if it's missing
date1 = date1.apply(lambda s: re.sub(r'(\d{1,2}\/\d{1}\/\d{4})\s(\d{1}:\d{2})', r'\1 0\2', s))

# Add a leading '0' to the 'date1' values if they match a specific date and time format
date1 = date1.apply(lambda s: '0' + s[0:] if re.match('\d{1}\/\d{1}\/\d{4}\s\d{2}:\d{2}', s) else s)

# Modify the 'date1' values by adding a leading '0' to the day component if it's missing
date1 = date1.apply(lambda s: s[0:3] + '0' + s[3:] if re.match('\d{2}\/\d{1}\/\d{4}\s\d{2}:\d{2}', s) else s)

# Convert the modified 'date1' values to datetime format with the specified format '%d/%m/%Y %H:%M'
date1 = pd.to_datetime(date1, format='%d/%m/%Y %H:%M')
date2 = pd.to_datetime(date2,format='%Y-%m-%d %H:%M:%S.%f')
df['date'] = pd.concat([date1,date2])
df = df.sort_values('date')

# %% [markdown]
# # Handling Separator Motor ERRORS and Missing Values

# %%
df['separator_pwr_kw_pv'].dtype

#missing values
df['separator_pwr_kw_pv'].isna().sum()

#errors
(df['separator_pwr_kw_pv'] == 'ERROR').sum()
df['separator_pwr_kw_pv'] = df['separator_pwr_kw_pv'].replace({'ERROR' : np.NaN})
df['separator_pwr_kw_pv'] = df['separator_pwr_kw_pv'].astype(float)
df['separator_pwr_kw_pv'] = df['separator_pwr_kw_pv'].interpolate()
df['separator_pwr_kw_pv'].isna().sum()
sns.distplot(df['separator_pwr_kw_pv'])
# Out:
# <AxesSubplot: xlabel='separator_pwr_kw_pv', ylabel='Density'>

# %%
plt.figure(figsize = (20,8))

plt.scatter(df['date'],df['separator_pwr_kw_pv'])

# %%
df[df['separator_pwr_kw_pv'] < 40]['separator_pwr_kw_pv'].count()
df['separator_pwr_kw_pv'] = df['separator_pwr_kw_pv'].apply(lambda x: np.NaN if x < 40 or x > 140 else x)
df['separator_pwr_kw_pv'] = df['separator_pwr_kw_pv'].interpolate(method='linear')
plt.figure(figsize = (20,8))

plt.scatter(df['date'],df['separator_pwr_kw_pv'])

# %%
(df['separator_pwr_kw_pv'].dtypes , df['separator_pwr_kw_pv'].isna().sum())
# Out:
# (dtype('float64'), 0)

# %% [markdown]
# # Separator Speed , Mill DP Handling Missing Values and ERRORS

# %% [markdown]
# **Separator Speed**

# %%
df['separator_speed_rpm_pv'].dtype
(df['separator_speed_rpm_pv'] == 'ERROR').sum()
df['separator_speed_rpm_pv'].replace({'ERROR' : np.NaN},inplace=True)
df['separator_speed_rpm_pv'] = df['separator_speed_rpm_pv'].astype(float)
df['separator_speed_rpm_pv'].isna().sum()
df['separator_speed_rpm_pv'] = df['separator_speed_rpm_pv'].interpolate()
sns.distplot(df['separator_speed_rpm_pv'])
# Out:
# <AxesSubplot: xlabel='separator_speed_rpm_pv', ylabel='Density'>

# %%
(df['separator_speed_rpm_pv'].dtypes , df['separator_speed_rpm_pv'].isna().sum())
# Out:
# (dtype('float64'), 0)

# %% [markdown]
# **Mill DP**

# %%
df['mill_dp_mbar_pv'].dtype
df['mill_dp_mbar_pv'].isna().sum() 
df['mill_dp_mbar_pv'].replace({'ERROR' : np.NaN},inplace=True)
df['mill_dp_mbar_pv'] = df['mill_dp_mbar_pv'].astype(float)
df['mill_dp_mbar_pv'] = df['mill_dp_mbar_pv'].interpolate()
sns.distplot(df['mill_dp_mbar_pv'])
# Out:
# <AxesSubplot: xlabel='mill_dp_mbar_pv', ylabel='Density'>

# %%
(df['mill_dp_mbar_pv'].dtypes , df['mill_dp_mbar_pv'].isna().sum())
# Out:
# (dtype('float64'), 0)

# %%
df.corr()
# Out:
#                               mill_motor_pwr_kw_pv  mill_dp_mbar_pv  \
# mill_motor_pwr_kw_pv                      1.000000         0.537087
# mill_dp_mbar_pv                           0.537087         1.000000
# separator_pwr_kw_pv                       0.248986         0.339031
# separator_speed_rpm_pv                    0.348933         0.263095
# blaine_cm3_g_pv                           0.018848        -0.017906
# total_feed_ton_h_pv                       0.710125         0.380345
# clinker_ton_h_pv                          0.593793         0.328417
# limestone_ton_h_pv                        0.294061         0.152594
# slag_ton_h_pv                             0.123954         0.255232
# gypsum_ton_h_pv                           0.424592         0.440435
# pozzolane_ton_h_pv                        0.011667         0.040183
# fly_ash_1_ton_h_pv                        0.135540        -0.030777
# fly_ash_2_ton_h_pv                        0.166973        -0.010769
# total_feed_ton_h_sp                       0.176212        -0.021809
# slag_ton_h_sp                            -0.009594         0.186381
# limestone_ton_h_sp                        0.079788         0.013476
# clinker_ton_h_sp                          0.098194        -0.050390
# pozzolane_ton_h_sp                       -0.059048         0.015355
# gypsum_ton_h_sp                           0.045157         0.217043
# fly_ash_1_ton_h_sp                        0.041800        -0.086556
# fly_ash_2_ton_h_sp                        0.071379        -0.070054
# fan_pwr_kw_pv                             0.046426         0.448173
# bf_out_press_mbar_pv                      0.493207         0.760365
# bf_dp_mbar_pv                             0.282081         0.265942
# mill_in_press_mbar_pv                    -0.285610        -0.033602
# mill_in_press_mbar_sp                    -0.163713        -0.048616
# mill_out_press_mbar_pv                    0.343935         0.816864
# mill_injection_water_m3_h_pv              0.501048         0.258475
# mill_vibration_mm_s_pv                    0.340178         0.116609
# gearbox_1_vibration_mm_s_pv               0.534295         0.260820
# gearbox_2_vibration_mm_s_pv               0.597843         0.330916
# hopper_level_mg_m3_pv                     0.104768        -0.028141
# grinding_aid_l_h_pv                       0.231456         0.166554
# grinding_aid_perc_sp                      0.048190        -0.030287
# fan_speed_perc_pv                         0.310313        -0.151482
# fan_speed_perc_sp                         0.181532         0.476915
# bf_dp_mbar_sp                             0.160066         0.081288
# is_enable_sp                              0.295069         0.170271
# is_clicked_sp                             0.252891         0.149391
#
#                               separator_pwr_kw_pv  separator_speed_rpm_pv  \
# mill_motor_pwr_kw_pv                     0.248986                0.348933
# mill_dp_mbar_pv                          0.339031                0.263095
# separator_pwr_kw_pv                      1.000000                0.315794
# separator_speed_rpm_pv                   0.315794                1.000000
# blaine_cm3_g_pv                         -0.035147               -0.069638
# total_feed_ton_h_pv                      0.073626               -0.035411
# clinker_ton_h_pv                         0.000394               -0.123968
# limestone_ton_h_pv                       0.021883                0.046601
# slag_ton_h_pv                            0.304069                0.332375
# gypsum_ton_h_pv                          0.338380                0.333738
# pozzolane_ton_h_pv                       0.013046                0.189247
# fly_ash_1_ton_h_pv                      -0.084852               -0.150166
# fly_ash_2_ton_h_pv                      -0.089658               -0.164416
# total_feed_ton_h_sp                     -0.171216               -0.352421
# slag_ton_h_sp                            0.263385                0.319009
# limestone_ton_h_sp                      -0.033254                0.012044
# clinker_ton_h_sp                        -0.196183               -0.360962
# pozzolane_ton_h_sp                      -0.013034                0.187201
# gypsum_ton_h_sp                          0.260342                0.298541
# fly_ash_1_ton_h_sp                      -0.113713               -0.205619
# fly_ash_2_ton_h_sp                      -0.123411               -0.215075
# fan_pwr_kw_pv                            0.098213                0.220122
# bf_out_press_mbar_pv                     0.215792                0.193783
# bf_dp_mbar_pv                           -0.060336               -0.021568
# mill_in_press_mbar_pv                   -0.079061               -0.032636
# mill_in_press_mbar_sp                   -0.032373               -0.018973
# mill_out_press_mbar_pv                   0.320074                0.281435
# mill_injection_water_m3_h_pv             0.033718                0.007973
# mill_vibration_mm_s_pv                   0.021757                0.020469
# gearbox_1_vibration_mm_s_pv              0.076677                0.053259
# gearbox_2_vibration_mm_s_pv              0.145598                0.115703
# hopper_level_mg_m3_pv                   -0.148262               -0.172955
# grinding_aid_l_h_pv                      0.081676                0.042294
# grinding_aid_perc_sp                    -0.100314               -0.205495
# fan_speed_perc_pv                        0.266445                0.344102
# fan_speed_perc_sp                        0.146698               -0.034496
# bf_dp_mbar_sp                           -0.102169               -0.043836
# is_enable_sp                             0.039434                0.012693
# is_clicked_sp                            0.034674                0.055215
#
#                               blaine_cm3_g_pv  total_feed_ton_h_pv  \
# mill_motor_pwr_kw_pv                 0.018848             0.710125
# mill_dp_mbar_pv                     -0.017906             0.380345
# separator_pwr_kw_pv                 -0.035147             0.073626
# separator_speed_rpm_pv              -0.069638            -0.035411
# blaine_cm3_g_pv                      1.000000             0.177222
# total_feed_ton_h_pv                  0.177222             1.000000
# clinker_ton_h_pv                     0.168719             0.916619
# limestone_ton_h_pv                   0.124732             0.227224
# slag_ton_h_pv                       -0.257377            -0.262474
# gypsum_ton_h_pv                     -0.118068             0.195740
# pozzolane_ton_h_pv                  -0.052158            -0.042410
# fly_ash_1_ton_h_pv                   0.204918             0.417526
# fly_ash_2_ton_h_pv                   0.124949             0.370153
# total_feed_ton_h_sp                  0.274061             0.601614
# slag_ton_h_sp                       -0.264144            -0.401538
# limestone_ton_h_sp                   0.115126            -0.006276
# clinker_ton_h_sp                     0.204725             0.518671
# pozzolane_ton_h_sp                  -0.072641            -0.152883
# gypsum_ton_h_sp                     -0.165343            -0.248573
# fly_ash_1_ton_h_sp                   0.212473             0.321673
# fly_ash_2_ton_h_sp                   0.133232             0.262672
# fan_pwr_kw_pv                       -0.033704             0.013678
# bf_out_press_mbar_pv                 0.107386             0.597935
# bf_dp_mbar_pv                        0.264683             0.608152
# mill_in_press_mbar_pv               -0.064373            -0.341315
# mill_in_press_mbar_sp               -0.008453            -0.171222
# mill_out_press_mbar_pv              -0.035264             0.270312
# mill_injection_water_m3_h_pv         0.068852             0.662020
# mill_vibration_mm_s_pv               0.090550             0.280579
# gearbox_1_vibration_mm_s_pv          0.091155             0.494496
# gearbox_2_vibration_mm_s_pv          0.065661             0.486346
# hopper_level_mg_m3_pv               -0.036074             0.174636
# grinding_aid_l_h_pv                  0.099645             0.291522
# grinding_aid_perc_sp                -0.073753             0.071602
# fan_speed_perc_pv                   -0.036285            -0.149350
# fan_speed_perc_sp                   -0.043732             0.263767
# bf_dp_mbar_sp                        0.244215             0.499874
# is_enable_sp                         0.091570             0.346490
# is_clicked_sp                        0.124089             0.284971
#
#                               clinker_ton_h_pv  limestone_ton_h_pv  \
# mill_motor_pwr_kw_pv                  0.593793            0.294061
# mill_dp_mbar_pv                       0.328417            0.152594
# separator_pwr_kw_pv                   0.000394            0.021883
# separator_speed_rpm_pv               -0.123968            0.046601
# blaine_cm3_g_pv                       0.168719            0.124732
# total_feed_ton_h_pv                   0.916619            0.227224
# clinker_ton_h_pv                      1.000000            0.040412
# limestone_ton_h_pv                    0.040412            1.000000
# slag_ton_h_pv                        -0.471359            0.170956
# gypsum_ton_h_pv                      -0.038592            0.352651
# pozzolane_ton_h_pv                    0.049802           -0.001760
# fly_ash_1_ton_h_pv                    0.383338            0.023189
# fly_ash_2_ton_h_pv                    0.355839           -0.010053
# total_feed_ton_h_sp                   0.640198            0.016026
# slag_ton_h_sp                        -0.593319            0.116040
# limestone_ton_h_sp                   -0.183147            0.938927
# clinker_ton_h_sp                      0.696611           -0.235007
# pozzolane_ton_h_sp                    0.005592           -0.032161
# gypsum_ton_h_sp                      -0.473404            0.216497
# fly_ash_1_ton_h_sp                    0.324332           -0.000297
# fly_ash_2_ton_h_sp                    0.290296           -0.019053
# fan_pwr_kw_pv                         0.016169            0.063032
# bf_out_press_mbar_pv                  0.550956            0.179610
# bf_dp_mbar_pv                         0.601768            0.040483
# mill_in_press_mbar_pv                -0.319046           -0.005902
# mill_in_press_mbar_sp                -0.171025            0.050773
# mill_out_press_mbar_pv                0.224850            0.173617
# mill_injection_water_m3_h_pv          0.748961           -0.212341
# mill_vibration_mm_s_pv                0.279123            0.272233
# gearbox_1_vibration_mm_s_pv           0.486818            0.226736
# gearbox_2_vibration_mm_s_pv           0.438623            0.312951
# hopper_level_mg_m3_pv                 0.213350           -0.081613
# grinding_aid_l_h_pv                   0.273311            0.049516
# grinding_aid_perc_sp                  0.128086           -0.114369
# fan_speed_perc_pv                    -0.164011           -0.127583
# fan_speed_perc_sp                     0.318197           -0.277001
# bf_dp_mbar_sp                         0.503946           -0.005650
# is_enable_sp                          0.317174            0.128565
# is_clicked_sp                         0.234288            0.152764
#
#                               slag_ton_h_pv  gypsum_ton_h_pv  ...  \
# mill_motor_pwr_kw_pv               0.123954         0.424592  ...
# mill_dp_mbar_pv                    0.255232         0.440435  ...
# separator_pwr_kw_pv                0.304069         0.338380  ...
# separator_speed_rpm_pv             0.332375         0.333738  ...
# blaine_cm3_g_pv                   -0.257377        -0.118068  ...
# total_feed_ton_h_pv               -0.262474         0.195740  ...
# clinker_ton_h_pv                  -0.471359        -0.038592  ...
# limestone_ton_h_pv                 0.170956         0.352651  ...
# slag_ton_h_pv                      1.000000         0.820641  ...
# gypsum_ton_h_pv                    0.820641         1.000000  ...
# pozzolane_ton_h_pv                -0.212599        -0.229992  ...
# fly_ash_1_ton_h_pv                -0.390495        -0.181900  ...
# fly_ash_2_ton_h_pv                -0.351076        -0.182049  ...
# total_feed_ton_h_sp               -0.669652        -0.347877  ...
# slag_ton_h_sp                      0.958855         0.718155  ...
# limestone_ton_h_sp                 0.155420         0.231688  ...
# clinker_ton_h_sp                  -0.807091        -0.555173  ...
# pozzolane_ton_h_sp                -0.238832        -0.287364  ...
# gypsum_ton_h_sp                    0.849001         0.827720  ...
# fly_ash_1_ton_h_sp                -0.410012        -0.229338  ...
# fly_ash_2_ton_h_sp                -0.372024        -0.230679  ...
# fan_pwr_kw_pv                      0.149626         0.219737  ...
# bf_out_press_mbar_pv              -0.056488         0.274373  ...
# bf_dp_mbar_pv                     -0.516778        -0.159925  ...
# mill_in_press_mbar_pv              0.049828        -0.072024  ...
# mill_in_press_mbar_sp              0.022801        -0.016733  ...
# mill_out_press_mbar_pv             0.272237         0.433462  ...
# mill_injection_water_m3_h_pv      -0.356275        -0.123798  ...
# mill_vibration_mm_s_pv            -0.204178        -0.055119  ...
# gearbox_1_vibration_mm_s_pv       -0.168270         0.077575  ...
# gearbox_2_vibration_mm_s_pv       -0.025086         0.213816  ...
# hopper_level_mg_m3_pv             -0.193747        -0.168207  ...
# grinding_aid_l_h_pv                0.034843         0.157024  ...
# grinding_aid_perc_sp              -0.003792        -0.043584  ...
# fan_speed_perc_pv                 -0.123086        -0.162569  ...
# fan_speed_perc_sp                  0.106076         0.169509  ...
# bf_dp_mbar_sp                     -0.558611        -0.243768  ...
# is_enable_sp                      -0.105650         0.038550  ...
# is_clicked_sp                     -0.075789         0.067966  ...
#
#                               gearbox_1_vibration_mm_s_pv  \
# mill_motor_pwr_kw_pv                             0.534295
# mill_dp_mbar_pv                                  0.260820
# separator_pwr_kw_pv                              0.076677
# separator_speed_rpm_pv                           0.053259
# blaine_cm3_g_pv                                  0.091155
# total_feed_ton_h_pv                              0.494496
# clinker_ton_h_pv                                 0.486818
# limestone_ton_h_pv                               0.226736
# slag_ton_h_pv                                   -0.168270
# gypsum_ton_h_pv                                  0.077575
# pozzolane_ton_h_pv                               0.178063
# fly_ash_1_ton_h_pv                               0.146921
# fly_ash_2_ton_h_pv                               0.137333
# total_feed_ton_h_sp                              0.154632
# slag_ton_h_sp                                   -0.260200
# limestone_ton_h_sp                               0.067129
# clinker_ton_h_sp                                 0.154747
# pozzolane_ton_h_sp                               0.150826
# gypsum_ton_h_sp                                 -0.230875
# fly_ash_1_ton_h_sp                               0.099583
# fly_ash_2_ton_h_sp                               0.086437
# fan_pwr_kw_pv                                    0.058834
# bf_out_press_mbar_pv                             0.375061
# bf_dp_mbar_pv                                    0.289019
# mill_in_press_mbar_pv                           -0.157802
# mill_in_press_mbar_sp                           -0.078870
# mill_out_press_mbar_pv                           0.238893
# mill_injection_water_m3_h_pv                     0.328626
# mill_vibration_mm_s_pv                           0.707950
# gearbox_1_vibration_mm_s_pv                      1.000000
# gearbox_2_vibration_mm_s_pv                      0.761392
# hopper_level_mg_m3_pv                            0.041097
# grinding_aid_l_h_pv                              0.121589
# grinding_aid_perc_sp                            -0.094711
# fan_speed_perc_pv                                0.186107
# fan_speed_perc_sp                               -0.037328
# bf_dp_mbar_sp                                    0.214237
# is_enable_sp                                     0.143542
# is_clicked_sp                                    0.139671
#
#                               gearbox_2_vibration_mm_s_pv  \
# mill_motor_pwr_kw_pv                             0.597843
# mill_dp_mbar_pv                                  0.330916
# separator_pwr_kw_pv                              0.145598
# separator_speed_rpm_pv                           0.115703
# blaine_cm3_g_pv                                  0.065661
# total_feed_ton_h_pv                              0.486346
# clinker_ton_h_pv                                 0.438623
# limestone_ton_h_pv                               0.312951
# slag_ton_h_pv                                   -0.025086
# gypsum_ton_h_pv                                  0.213816
# pozzolane_ton_h_pv                               0.176930
# fly_ash_1_ton_h_pv                               0.089517
# fly_ash_2_ton_h_pv                               0.092322
# total_feed_ton_h_sp                              0.069136
# slag_ton_h_sp                                   -0.127660
# limestone_ton_h_sp                               0.143736
# clinker_ton_h_sp                                 0.040222
# pozzolane_ton_h_sp                               0.142803
# gypsum_ton_h_sp                                 -0.104467
# fly_ash_1_ton_h_sp                               0.035450
# fly_ash_2_ton_h_sp                               0.034376
# fan_pwr_kw_pv                                    0.071040
# bf_out_press_mbar_pv                             0.390812
# bf_dp_mbar_pv                                    0.212803
# mill_in_press_mbar_pv                           -0.164284
# mill_in_press_mbar_sp                           -0.059476
# mill_out_press_mbar_pv                           0.305445
# mill_injection_water_m3_h_pv                     0.269219
# mill_vibration_mm_s_pv                           0.696259
# gearbox_1_vibration_mm_s_pv                      0.761392
# gearbox_2_vibration_mm_s_pv                      1.000000
# hopper_level_mg_m3_pv                            0.009089
# grinding_aid_l_h_pv                              0.116887
# grinding_aid_perc_sp                            -0.123103
# fan_speed_perc_pv                                0.254851
# fan_speed_perc_sp                               -0.050408
# bf_dp_mbar_sp                                    0.127974
# is_enable_sp                                     0.159391
# is_clicked_sp                                    0.160357
#
#                               hopper_level_mg_m3_pv  grinding_aid_l_h_pv  \
# mill_motor_pwr_kw_pv                       0.104768             0.231456
# mill_dp_mbar_pv                           -0.028141             0.166554
# separator_pwr_kw_pv                       -0.148262             0.081676
# separator_speed_rpm_pv                    -0.172955             0.042294
# blaine_cm3_g_pv                           -0.036074             0.099645
# total_feed_ton_h_pv                        0.174636             0.291522
# clinker_ton_h_pv                           0.213350             0.273311
# limestone_ton_h_pv                        -0.081613             0.049516
# slag_ton_h_pv                             -0.193747             0.034843
# gypsum_ton_h_pv                           -0.168207             0.157024
# pozzolane_ton_h_pv                        -0.102392            -0.153273
# fly_ash_1_ton_h_pv                         0.099907             0.089717
# fly_ash_2_ton_h_pv                         0.178989             0.093298
# total_feed_ton_h_sp                        0.202456             0.093247
# slag_ton_h_sp                             -0.204122            -0.019292
# limestone_ton_h_sp                        -0.106342            -0.042371
# clinker_ton_h_sp                           0.238090             0.087990
# pozzolane_ton_h_sp                        -0.114709            -0.187311
# gypsum_ton_h_sp                           -0.214486             0.000690
# fly_ash_1_ton_h_sp                         0.088816             0.060992
# fly_ash_2_ton_h_sp                         0.166480             0.059054
# fan_pwr_kw_pv                             -0.128528            -0.007241
# bf_out_press_mbar_pv                       0.027593             0.188608
# bf_dp_mbar_pv                              0.114923             0.118298
# mill_in_press_mbar_pv                     -0.021921            -0.135151
# mill_in_press_mbar_sp                     -0.090664            -0.028868
# mill_out_press_mbar_pv                    -0.085990             0.125916
# mill_injection_water_m3_h_pv               0.266322             0.294776
# mill_vibration_mm_s_pv                    -0.007233            -0.046701
# gearbox_1_vibration_mm_s_pv                0.041097             0.121589
# gearbox_2_vibration_mm_s_pv                0.009089             0.116887
# hopper_level_mg_m3_pv                      1.000000             0.011266
# grinding_aid_l_h_pv                        0.011266             1.000000
# grinding_aid_perc_sp                       0.334701             0.413605
# fan_speed_perc_pv                          0.134590             0.035741
# fan_speed_perc_sp                          0.174042             0.258575
# bf_dp_mbar_sp                              0.077469             0.065129
# is_enable_sp                               0.065842             0.198226
# is_clicked_sp                              0.050379             0.137410
#
#                               grinding_aid_perc_sp  fan_speed_perc_pv  \
# mill_motor_pwr_kw_pv                      0.048190           0.310313
# mill_dp_mbar_pv                          -0.030287          -0.151482
# separator_pwr_kw_pv                      -0.100314           0.266445
# separator_speed_rpm_pv                   -0.205495           0.344102
# blaine_cm3_g_pv                          -0.073753          -0.036285
# total_feed_ton_h_pv                       0.071602          -0.149350
# clinker_ton_h_pv                          0.128086          -0.164011
# limestone_ton_h_pv                       -0.114369          -0.127583
# slag_ton_h_pv                            -0.003792          -0.123086
# gypsum_ton_h_pv                          -0.043584          -0.162569
# pozzolane_ton_h_pv                       -0.302493          -0.030308
# fly_ash_1_ton_h_pv                        0.004805           0.024962
# fly_ash_2_ton_h_pv                        0.122026           0.015635
# total_feed_ton_h_sp                       0.107264          -0.254810
# slag_ton_h_sp                             0.002084          -0.230617
# limestone_ton_h_sp                       -0.119036          -0.267743
# clinker_ton_h_sp                          0.174350          -0.252915
# pozzolane_ton_h_sp                       -0.317842                NaN
# gypsum_ton_h_sp                          -0.029314          -0.205433
# fly_ash_1_ton_h_sp                        0.007054                NaN
# fly_ash_2_ton_h_sp                        0.112741                NaN
# fan_pwr_kw_pv                            -0.216711           0.120790
# bf_out_press_mbar_pv                     -0.138114           0.028405
# bf_dp_mbar_pv                            -0.160313           0.305215
# mill_in_press_mbar_pv                    -0.107206           0.246377
# mill_in_press_mbar_sp                    -0.165161          -0.330322
# mill_out_press_mbar_pv                   -0.139623          -0.052416
# mill_injection_water_m3_h_pv              0.234269           0.357411
# mill_vibration_mm_s_pv                   -0.227007           0.350863
# gearbox_1_vibration_mm_s_pv              -0.094711           0.186107
# gearbox_2_vibration_mm_s_pv              -0.123103           0.254851
# hopper_level_mg_m3_pv                     0.334701           0.134590
# grinding_aid_l_h_pv                       0.413605           0.035741
# grinding_aid_perc_sp                      1.000000                NaN
# fan_speed_perc_pv                              NaN           1.000000
# fan_speed_perc_sp                         0.346010                NaN
# bf_dp_mbar_sp                            -0.190940                NaN
# is_enable_sp                              0.079286                NaN
# is_clicked_sp                             0.004714                NaN
#
#                               fan_speed_perc_sp  bf_dp_mbar_sp  is_enable_sp  \
# mill_motor_pwr_kw_pv                   0.181532       0.160066      0.295069
# mill_dp_mbar_pv                        0.476915       0.081288      0.170271
# separator_pwr_kw_pv                    0.146698      -0.102169      0.039434
# separator_speed_rpm_pv                -0.034496      -0.043836      0.012693
# blaine_cm3_g_pv                       -0.043732       0.244215      0.091570
# total_feed_ton_h_pv                    0.263767       0.499874      0.346490
# clinker_ton_h_pv                       0.318197       0.503946      0.317174
# limestone_ton_h_pv                    -0.277001      -0.005650      0.128565
# slag_ton_h_pv                          0.106076      -0.558611     -0.105650
# gypsum_ton_h_pv                        0.169509      -0.243768      0.038550
# pozzolane_ton_h_pv                    -0.222684       0.037199     -0.027991
# fly_ash_1_ton_h_pv                     0.038057       0.394372      0.149789
# fly_ash_2_ton_h_pv                     0.063092       0.325780      0.136756
# total_feed_ton_h_sp                    0.061233       0.592247      0.263844
# slag_ton_h_sp                          0.079963      -0.590068     -0.143167
# limestone_ton_h_sp                    -0.368376      -0.065125      0.065319
# clinker_ton_h_sp                       0.150943       0.525161      0.224970
# pozzolane_ton_h_sp                    -0.248019       0.018420     -0.056739
# gypsum_ton_h_sp                        0.050957      -0.399269     -0.086075
# fly_ash_1_ton_h_sp                     0.005057       0.367125      0.111657
# fly_ash_2_ton_h_sp                     0.019973       0.300129      0.104006
# fan_pwr_kw_pv                          0.239840       0.160722     -0.022090
# bf_out_press_mbar_pv                   0.459893       0.502325      0.217289
# bf_dp_mbar_pv                          0.207587       0.904432      0.259730
# mill_in_press_mbar_pv                  0.011871      -0.109393     -0.289310
# mill_in_press_mbar_sp                 -0.094120      -0.050508     -0.245344
# mill_out_press_mbar_pv                 0.458166       0.084578      0.069649
# mill_injection_water_m3_h_pv           0.439397       0.386428      0.225331
# mill_vibration_mm_s_pv                -0.312958       0.105348      0.066662
# gearbox_1_vibration_mm_s_pv           -0.037328       0.214237      0.143542
# gearbox_2_vibration_mm_s_pv           -0.050408       0.127974      0.159391
# hopper_level_mg_m3_pv                  0.174042       0.077469      0.065842
# grinding_aid_l_h_pv                    0.258575       0.065129      0.198226
# grinding_aid_perc_sp                   0.346010      -0.190940      0.079286
# fan_speed_perc_pv                           NaN            NaN           NaN
# fan_speed_perc_sp                      1.000000       0.073362      0.117822
# bf_dp_mbar_sp                          0.073362       1.000000      0.227539
# is_enable_sp                           0.117822       0.227539      1.000000
# is_clicked_sp                          0.030858       0.261689      0.811090
#
#                               is_clicked_sp
# mill_motor_pwr_kw_pv               0.252891
# mill_dp_mbar_pv                    0.149391
# separator_pwr_kw_pv                0.034674
# separator_speed_rpm_pv             0.055215
# blaine_cm3_g_pv                    0.124089
# total_feed_ton_h_pv                0.284971
# clinker_ton_h_pv                   0.234288
# limestone_ton_h_pv                 0.152764
# slag_ton_h_pv                     -0.075789
# gypsum_ton_h_pv                    0.067966
# pozzolane_ton_h_pv                 0.014325
# fly_ash_1_ton_h_pv                 0.113696
# fly_ash_2_ton_h_pv                 0.116081
# total_feed_ton_h_sp                0.214551
# slag_ton_h_sp                     -0.106511
# limestone_ton_h_sp                 0.102238
# clinker_ton_h_sp                   0.147493
# pozzolane_ton_h_sp                -0.011155
# gypsum_ton_h_sp                   -0.031267
# fly_ash_1_ton_h_sp                 0.080203
# fly_ash_2_ton_h_sp                 0.088935
# fan_pwr_kw_pv                      0.027866
# bf_out_press_mbar_pv               0.219631
# bf_dp_mbar_pv                      0.281662
# mill_in_press_mbar_pv             -0.234703
# mill_in_press_mbar_sp             -0.203459
# mill_out_press_mbar_pv             0.069487
# mill_injection_water_m3_h_pv       0.119921
# mill_vibration_mm_s_pv             0.103606
# gearbox_1_vibration_mm_s_pv        0.139671
# gearbox_2_vibration_mm_s_pv        0.160357
# hopper_level_mg_m3_pv              0.050379
# grinding_aid_l_h_pv                0.137410
# grinding_aid_perc_sp               0.004714
# fan_speed_perc_pv                       NaN
# fan_speed_perc_sp                  0.030858
# bf_dp_mbar_sp                      0.261689
# is_enable_sp                       0.811090
# is_clicked_sp                      1.000000
#
# [39 rows x 39 columns]

# %%
df.shape
# Out:
# (242550, 130)

# %%
# Maybe we should examine and gypsum_ton_h_pv
df['gypsum_ton_h_pv'].isna().sum()
# df['gypsum_ton_h_pv'].describe()
# Out:
# 62107

# %%
df['gypsum_ton_h_sp'].isna().sum()
# Out:
# 62113

# %%
df['slag_ton_h_pv'].isna().sum()
df['slag_ton_h_pv'].describe()
# Out:
# count    180441.000000
# mean          5.933232
# std           9.742941
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          19.450000
# max          47.180000
# Name: slag_ton_h_pv, dtype: float64

# %% [markdown]
# # Statistics - Diagramms

# %%
# Create separate histograms for each variable
plt.figure(figsize=(10, 6))

plt.subplot(1, 4, 1)
sns.histplot(data=df, x='separator_speed_rpm_pv', bins=10)
plt.title('Mill Speed')

plt.subplot(1, 4, 2)
sns.histplot(data=df, x='mill_dp_mbar_pv', bins=10)
plt.title('Differential Pressure')

plt.subplot(1, 4, 3)
sns.histplot(data=df, x='separator_pwr_kw_pv', bins=10)
plt.title('Separator Power')

plt.subplot(1, 4, 4)
sns.histplot(data=df, x='mill_motor_pwr_kw_pv', bins=10)
plt.title('Mill Power')

plt.tight_layout()
plt.show()

# %%
# Create a scatter plot between 'mill_speed' and 'separator_power'
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='separator_speed_rpm_pv', y='separator_pwr_kw_pv')
plt.xlabel('Mill Speed')
plt.ylabel('Separator Power')
plt.title('Relationship between Mill Speed and Separator Power')
plt.show()

# Create a scatter plot between 'differential_pressure' and 'separator_power'
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='mill_dp_mbar_pv', y='separator_pwr_kw_pv')
plt.xlabel('Differential Pressure')
plt.ylabel('Separator Power')
plt.title('Relationship between Differential Pressure and Separator Power')
plt.show()

# %% [markdown]
# #  Inputs And Outputs for Mill Differential Pressure Block

# %%
df[['total_feed_ton/h_pv','total_feed_ton/h_sp']]
# Out:
#        total_feed_ton/h_pv total_feed_ton/h_sp
# 0                    85.82                85.0
# 1                     85.5                85.0
# 2                    57.92                83.0
# 3                    57.72                83.0
# 4                    58.01                83.0
# ...                    ...                 ...
# 242545                 NaN                 NaN
# 242546                 NaN                 NaN
# 242547                 NaN                 NaN
# 242548                 NaN                 NaN
# 242549                 NaN                 NaN
#
# [242550 rows x 2 columns]

# %%
df[['total_feed_ton/h_pv','total_feed_ton/h_sp']]

df[['fly_ash_1_perc_pv','fly_ash_1_perc_sp','fly_ash_1_ton/h_pv','fly_ash_1_ton/h_sp']]

df[['fly_ash_2_perc_pv','fly_ash_2_perc_sp','fly_ash_2_ton/h_pv','fly_ash_2_ton/h_sp']].sample(30)

df['main_fan_speed_rpm_pv']

df['separator_speed_rpm_pv']

df[['grinding_pressure_bar_sp','grinding_pressure_bar_pv']]

df[['mill_injection_water_m3/h_pv','mill_injection_water_perc_sp']]

df['bucket_elv_mtr_pwr_kw_pv']
# Out:
# 0         4.88
# 1         4.83
# 2         4.82
# 3         4.85
# 4         4.88
#           ...
# 242545    4.82
# 242546    4.87
# 242547    4.82
# 242548    4.81
# 242549    4.81
# Name: bucket_elv_mtr_pwr_kw_pv, Length: 242550, dtype: object

# %%
plt.figure(figsize=(20,8))

plt.scatter(df[df['cement_type_cpii_bool_pv'] == 1]['date'],df[df['cement_type_cpii_bool_pv'] == 1]['separator_pwr_kw_pv'])
plt.scatter(df[df['cement_type_cpii_bool_pv'] == 0]['date'],df[df['cement_type_cpii_bool_pv'] == 0]['separator_pwr_kw_pv'])

# %%
df[['separator_speed_rpm_pv','mill_dp_mbar_pv','separator_pwr_kw_pv','cement_type_cpii_bool_pv','cement_type_cpiv_bool_pv']]
# Out:
#         separator_speed_rpm_pv  mill_dp_mbar_pv  separator_pwr_kw_pv  \
# 0                       747.14            31.17                56.13
# 1                       746.87            31.37                56.83
# 2                       717.51            29.79                60.41
# 3                       735.89            30.51                55.76
# 4                       736.68            31.61                55.89
# ...                        ...              ...                  ...
# 242545                  767.68            32.83                57.76
# 242546                  768.10            32.91                57.00
# 242547                  769.11            33.65                57.14
# 242548                  769.27            35.03                57.44
# 242549                  791.40            36.42                58.03
#
#        cement_type_cpii_bool_pv cement_type_cpiv_bool_pv
# 0                           0.0                      1.0
# 1                           0.0                      1.0
# 2                           0.0                      1.0
# 3                           0.0                      1.0
# 4                           0.0                      1.0
# ...                         ...                      ...
# 242545                      1.0                      0.0
# 242546                      1.0                      0.0
# 242547                      1.0                      0.0
# 242548                      1.0                      0.0
# 242549                      1.0                      0.0
#
# [242550 rows x 5 columns]

# %%
df['separator_pwr_kw_pv'].plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Exploring Diversing Values

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
sns.distplot(df[df['mill_dp_mbar_pv'] < 15]['separator_pwr_kw_pv'])
plt.title('Separator Motor Distribution for Mill DP < 15 mBar')

plt.subplot(132)
sns.distplot(df[df['mill_dp_mbar_pv'] > 15]['separator_pwr_kw_pv'])
plt.title('Separator Motor Distribution for Mill DP > 15 mBar')
# Out:
# Text(0.5, 1.0, 'Separator Motor Distribution for Mill DP > 15 mBar')

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
sns.distplot(df[df['mill_dp_mbar_pv'] < 15]['mill_motor_pwr_kw_pv'])
plt.title('Mill Motor Distribution for Mill DP < 15 mBar')

plt.subplot(132)
sns.distplot(df[df['mill_dp_mbar_pv'] > 15]['mill_motor_pwr_kw_pv'])
plt.title('Mill Motor Distribution for Mill DP > 15 mBar')
# Out:
# Text(0.5, 1.0, 'Mill Motor Distribution for Mill DP > 15 mBar')

# %%
plt.figure(figsize=(15,5))

plt.subplot(141)
sns.distplot(df[df['cement_type_cpii_bool_pv'] == 1]['separator_pwr_kw_pv'])
plt.title('Separator Motor Distribution for CPII')

plt.subplot(142)
sns.distplot(df[df['cement_type_cpii_bool_pv'] == 0]['separator_pwr_kw_pv'])
plt.title('Separator Motor Distribution for CPIV')

plt.subplot(143)
sns.distplot(df[df['cement_type_cpii_bool_pv'] == 1]['mill_motor_pwr_kw_pv'])
plt.title('Mill Motor Distribution for CPII')

plt.subplot(144)
sns.distplot(df[df['cement_type_cpii_bool_pv'] == 0]['mill_motor_pwr_kw_pv'])
plt.title('Mill Motor Distribution for CPIV')
# Out:
# Text(0.5, 1.0, 'Mill Motor Distribution for CPIV')

# %% [markdown]
# **Possible Time Delay**

# %%
from scipy import signal
x = df['mill_dp_mbar_pv']
y = df['separator_pwr_kw_pv']
correlation = signal.correlate(x-np.mean(x), y - np.mean(y), mode="full")
lags = signal.correlation_lags(len(x), len(y), mode="full")
lag = lags[np.argmax(abs(correlation))]
lag
# Out:
# 2

# %%
df[['separator_speed_rpm_pv','mill_dp_mbar_pv','separator_pwr_kw_pv','cement_type_cpii_bool_pv','cement_type_cpiv_bool_pv']]
# Out:
#         separator_speed_rpm_pv  mill_dp_mbar_pv  separator_pwr_kw_pv  \
# 0                       747.14            31.17                56.13
# 1                       746.87            31.37                56.83
# 2                       717.51            29.79                60.41
# 3                       735.89            30.51                55.76
# 4                       736.68            31.61                55.89
# ...                        ...              ...                  ...
# 242545                  767.68            32.83                57.76
# 242546                  768.10            32.91                57.00
# 242547                  769.11            33.65                57.14
# 242548                  769.27            35.03                57.44
# 242549                  791.40            36.42                58.03
#
#        cement_type_cpii_bool_pv cement_type_cpiv_bool_pv
# 0                           0.0                      1.0
# 1                           0.0                      1.0
# 2                           0.0                      1.0
# 3                           0.0                      1.0
# 4                           0.0                      1.0
# ...                         ...                      ...
# 242545                      1.0                      0.0
# 242546                      1.0                      0.0
# 242547                      1.0                      0.0
# 242548                      1.0                      0.0
# 242549                      1.0                      0.0
#
# [242550 rows x 5 columns]

# %% [markdown]
# # Gypsum examination - as external factor

# %%
# print(df['gypsum_ton/h_pv'].isnull().sum())
# print(df['gypsum_ton_h_pv'].isnull().sum())
result1 = df[df['gypsum_ton/h_pv'].isnull() & df['gypsum_ton_h_pv'].isnull()]
result1
# Checking if they are rows that have a non-Nan value in the same rows
result2 = df[df['gypsum_ton/h_pv'].notnull() & df['gypsum_ton_h_pv'].notnull()].all(axis=1)
result2
# Combined Columns
df['gypsum_ton/h_pv_NEW'] = df['gypsum_ton/h_pv'].fillna(df['gypsum_ton_h_pv'])

df['gypsum_ton/h_pv_NEW'].isna().sum()
#removing the Nan values
# df = df.dropna(subset=['gypsum_ton/h_pv_NEW'])
# Out:
# 4

# %%
error_count = (df['gypsum_ton/h_pv_NEW'] == 'ERROR').sum()
df['gypsum_ton/h_pv_NEW'] = df['gypsum_ton/h_pv_NEW'].replace('ERROR', np.nan)
df['gypsum_ton/h_pv_NEW'] = pd.to_numeric(df['gypsum_ton/h_pv_NEW'])
df['gypsum_ton/h_pv_NEW'] = df['gypsum_ton/h_pv_NEW'].fillna((df['gypsum_ton/h_pv_NEW'].shift() + df['gypsum_ton/h_pv_NEW'].shift(-1)) / 2)

# %%
df['gypsum_ton/h_pv_NEW'].isna().sum()
# Out:
# 0

# %%
# Assuming you have a DataFrame named df and want to visualize the correlations of 'variable1'
variable1_correlations = df.corr()['separator_pwr_kw_pv'].drop('separator_pwr_kw_pv')

# Sort correlations in descending order
sorted_correlations = variable1_correlations.sort_values(ascending=False)

# Create a correlation matrix heatmap
correlation_matrix = pd.DataFrame(sorted_correlations)
plt.figure(figsize=(10, len(correlation_matrix)*0.4))  # Adjust the figsize
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", cbar=False)
plt.title("Correlations of separator_pwr_kw_pv with Other Variables (Sorted)")
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels
plt.show()

# %% [markdown]
# # Predictions LSTM

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
df = df.sort_values('date')
df = df[['date','separator_speed_rpm_pv', 'mill_dp_mbar_pv', 'separator_pwr_kw_pv']]
df = df.replace('ERROR', np.nan)  # Replace 'ERROR' with NaN or any appropriate value
df = df.dropna()  # Drop rows with missing values

# %%
#Scaling my data 
scaler = MinMaxScaler()
df[['separator_speed_rpm_pv', 'mill_dp_mbar_pv', 'separator_pwr_kw_pv']] = scaler.fit_transform(df[['separator_speed_rpm_pv', 'mill_dp_mbar_pv', 'separator_pwr_kw_pv']])

# %%
# Set the percentage of data to be used for training (e.g., 80%)
train_percentage = 0.8

# Calculate the index to split the data
train_size = int(len(df) * train_percentage)

# Split the data into training and testing sets
train_data = df[:train_size]
test_data = df[train_size:]

# %%
# Define the number of time steps (e.g., 10)
time_steps = 10

def create_sequences(data):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data.iloc[i:i+time_steps, 1:3].values)
        y.append(data.iloc[i+time_steps, 3])
    return np.array(X), np.array(y)

# Create sequences for training and testing data
X_train, y_train = create_sequences(train_data)
X_test, y_test = create_sequences(test_data)

def create_sequences(data):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data.iloc[i:i+time_steps, 1:3].values)
        y.append(data.iloc[i+time_steps, 3])
    return np.array(X), np.array(y).astype(np.float32)

X_train, y_train = create_sequences(train_data)
X_test, y_test = create_sequences(test_data)

# %%
# Define the model architecture
model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(time_steps, 2)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 6064/6064 [==============================] - 27s 4ms/step - loss: 4.1890e-04
# Epoch 2/10
# 6064/6064 [==============================] - 26s 4ms/step - loss: 4.0067e-04
# Epoch 3/10
# 6064/6064 [==============================] - 26s 4ms/step - loss: 3.9716e-04
# Epoch 4/10
# 6064/6064 [==============================] - 26s 4ms/step - loss: 3.9517e-04
# Epoch 5/10
# 6064/6064 [==============================] - 27s 4ms/step - loss: 3.9404e-04
# Epoch 6/10
# 6064/6064 [==============================] - 27s 4ms/step - loss: 3.9351e-04
# Epoch 7/10
# 6064/6064 [==============================] - 27s 4ms/step - loss: 3.9163e-04
# Epoch 8/10
# 6064/6064 [==============================] - 28s 5ms/step - loss: 3.9101e-04
# Epoch 9/10
# 6064/6064 [==============================] - 27s 5ms/step - loss: 3.9070e-04
# Epoch 10/10
# 6064/6064 [==============================] - 28s 5ms/step - loss: 3.9014e-04

# %%
# Evaluate the model on the testing data
loss = model.evaluate(X_test, y_test)

# Make predictions on the testing data
predictions = model.predict(X_test)

# Rescale the original target values
y_test = y_test.reshape(-1, 1)
y_test = scaler.inverse_transform(np.concatenate((np.zeros((y_test.shape[0], 2)), y_test), axis=1))[:, -1]

# Rescale the predicted values
predictions = predictions.reshape(-1, 1)
predictions = scaler.inverse_transform(np.concatenate((np.zeros((predictions.shape[0], 2)), predictions), axis=1))[:, -1]

from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, predictions))

# Calculate MAPE
mape = mean_absolute_percentage_error(y_test, predictions)

# Calculate R^2
r2 = r2_score(y_test, predictions)

print('RMSE:', rmse)
print('MAPE:', mape)
print('R^2:', r2)
# Out:
# 1516/1516 [==============================] - 4s 2ms/step - loss: 2.2059e-04
# 1516/1516 [==============================] - 4s 2ms/step
# RMSE: 1.293623388300506
# MAPE: 0.013844766893450296
# R^2: 0.23076261858913982

# %%
import matplotlib.pyplot as plt

# Plotting the actual prices
plt.plot(y_test, label='Actual')

# Plotting the predicted prices
plt.plot(predictions, label='Predicted')

plt.xlabel('Time')
plt.ylabel('KW')
plt.title('Actual vs. Predicted KW')
plt.legend()
plt.show()

# %% [markdown]
# # LSTM with cement type as external factor

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
df = df.sort_values('date')
df = df[['date','separator_speed_rpm_pv', 'mill_dp_mbar_pv', 'cement_type_cpii_bool_pv','separator_pwr_kw_pv']]
df = df.replace('ERROR', np.nan)  # Replace 'ERROR' with NaN or any appropriate value
df = df.dropna()  # Drop rows with missing values

# Convert the boolean feature to integer (0 or 1)
df['cement_type_cpii_bool_pv'] = df['cement_type_cpii_bool_pv'].astype(float)

# Normalize the input features using MinMaxScaler
scaler = MinMaxScaler()
df[['separator_speed_rpm_pv', 'mill_dp_mbar_pv','cement_type_cpii_bool_pv', 'separator_pwr_kw_pv']] = scaler.fit_transform(df[['separator_speed_rpm_pv', 'mill_dp_mbar_pv', 'cement_type_cpii_bool_pv','separator_pwr_kw_pv']])

# %%
# Set the percentage of data to be used for training (e.g., 80%)
train_percentage = 0.8

# Calculate the index to split the data
train_size = int(len(df) * train_percentage)

# Split the data into training and testing sets
train_data = df[:train_size]
test_data = df[train_size:]

# %%
# Define the number of time steps (e.g., 10)
time_steps = 10
def create_sequences(data):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data.iloc[i:i+time_steps, 1:4].values)  # Adjust the range of columns based on your data
        y.append(data.iloc[i+time_steps, 4])
    return np.array(X), np.array(y).astype(np.float32)

# %%
X_train, y_train = create_sequences(train_data)
X_test, y_test = create_sequences(test_data)


model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(time_steps, 3)))  # Adjust the input shape based on the number of features
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 6064/6064 [==============================] - 27s 4ms/step - loss: 4.2604e-04
# Epoch 2/10
# 6064/6064 [==============================] - 26s 4ms/step - loss: 4.0433e-04
# Epoch 3/10
# 6064/6064 [==============================] - 26s 4ms/step - loss: 3.9869e-04
# Epoch 4/10
# 6064/6064 [==============================] - 27s 5ms/step - loss: 3.9652e-04
# Epoch 5/10
# 6064/6064 [==============================] - 28s 5ms/step - loss: 3.9564e-04
# Epoch 6/10
# 6064/6064 [==============================] - 28s 5ms/step - loss: 3.9355e-04
# Epoch 7/10
# 6064/6064 [==============================] - 28s 5ms/step - loss: 3.9200e-04
# Epoch 8/10
# 6064/6064 [==============================] - 28s 5ms/step - loss: 3.9147e-04
# Epoch 9/10
# 6064/6064 [==============================] - 28s 5ms/step - loss: 3.9029e-04
# Epoch 10/10
# 6064/6064 [==============================] - 28s 5ms/step - loss: 3.9007e-04

# %%
# Evaluate the model on the testing data
loss = model.evaluate(X_test, y_test)

# Make predictions on the testing data
predictions = model.predict(X_test)

# Rescale the original target values
y_test = y_test.reshape(-1, 1)
y_test = scaler.inverse_transform(np.concatenate((np.zeros((y_test.shape[0], 3)), y_test), axis=1))[:, -1]
# y_test_rescaled = scaler.inverse_transform(y_test)

# Rescale the predicted values
predictions = predictions.reshape(-1, 1)
predictions = scaler.inverse_transform(np.concatenate((np.zeros((predictions.shape[0], 3)), predictions), axis=1))[:, -1]
# predictions_rescaled = scaler.inverse_transform(predictions)
# Out:
# 1516/1516 [==============================] - 4s 2ms/step - loss: 2.1715e-04
# 1516/1516 [==============================] - 4s 2ms/step

# %%
y_test.shape
X_train[10000,:,0]
X_train[:,:,0].max()
# Out:
# 1.0

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score, mean_absolute_error
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, predictions))

# Calculate MAPE
mape = mean_absolute_percentage_error(y_test, predictions)

# Calculate R^2
r2 = r2_score(y_test, predictions)

MAE = mean_absolute_error(y_test, predictions)

print('RMSE:', rmse)
print('MAPE:', mape)
print('R^2:', r2)
print("MAE:", MAE)
# Out:
# RMSE: 1.2835073193503366
# MAPE: 0.013588180355222981
# R^2: 0.24276864800285214
# MAE: 0.785710703237164

# %%
import matplotlib.pyplot as plt

# Create a range of dates for plotting
dates = test_data['date'].iloc[time_steps:].values

# Plotting the actual prices
plt.plot(dates, y_test, label='Actual')

# Plotting the predicted prices
plt.plot(dates, predictions, label='Predicted')

plt.xlabel('Date')
plt.ylabel('KW')
plt.title('Actual vs. Predicted KW')
plt.legend()
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# # LSTM ADD gypsum_ton_h_pv

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
df = df.sort_values('date')
df = df[['date','separator_speed_rpm_pv', 'mill_dp_mbar_pv', 'cement_type_cpii_bool_pv','gypsum_ton/h_pv_NEW', 'separator_pwr_kw_pv']]
df = df.replace('ERROR', np.nan)  # Replace 'ERROR' with NaN or any appropriate value
df = df.dropna()  # Drop rows with missing values

# Convert the boolean feature to integer (0 or 1)
df['cement_type_cpii_bool_pv'] = df['cement_type_cpii_bool_pv'].astype(float)

# Normalize the input features using MinMaxScaler
scaler = MinMaxScaler()
df[['separator_speed_rpm_pv', 'mill_dp_mbar_pv', 'cement_type_cpii_bool_pv','gypsum_ton/h_pv_NEW','separator_pwr_kw_pv']] = scaler.fit_transform(df[['separator_speed_rpm_pv', 'mill_dp_mbar_pv', 'cement_type_cpii_bool_pv','separator_pwr_kw_pv','separator_pwr_kw_pv']])

# %%
# Set the percentage of data to be used for training (e.g., 80%)
train_percentage = 0.8

# Calculate the index to split the data
train_size = int(len(df) * train_percentage)

# Split the data into training and testing sets
train_data = df[:train_size]
test_data = df[train_size:]

# %%
# Set the percentage of data to be used for training (e.g., 80%)
train_percentage = 0.8

# Calculate the index to split the data
train_size = int(len(df) * train_percentage)

# Split the data into training and testing sets
train_data = df[:train_size]
test_data = df[train_size:]# Define the number of time steps (e.g., 10)
time_steps = 10
def create_sequences(data):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data.iloc[i:i+time_steps, 1:5].values)  # Adjust the range of columns based on your data
        y.append(data.iloc[i+time_steps, 5])
    return np.array(X), np.array(y).astype(np.float32)

# %%
X_train, y_train = create_sequences(train_data)
X_test, y_test = create_sequences(test_data)


model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(time_steps, 4)))  # Adjust the input shape based on the number of features
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 6064/6064 [==============================] - 28s 4ms/step - loss: 3.3121e-04
# Epoch 2/10
# 6064/6064 [==============================] - 27s 4ms/step - loss: 3.1398e-04
# Epoch 3/10
# 6064/6064 [==============================] - 28s 5ms/step - loss: 3.1152e-04
# Epoch 4/10
# 6064/6064 [==============================] - 29s 5ms/step - loss: 3.1046e-04
# Epoch 5/10
# 6064/6064 [==============================] - 29s 5ms/step - loss: 3.0957e-04
# Epoch 6/10
# 6064/6064 [==============================] - 29s 5ms/step - loss: 3.0885e-04
# Epoch 7/10
# 6064/6064 [==============================] - 29s 5ms/step - loss: 3.0852e-04
# Epoch 8/10
# 6064/6064 [==============================] - 29s 5ms/step - loss: 3.0775e-04
# Epoch 9/10
# 6064/6064 [==============================] - 29s 5ms/step - loss: 3.0693e-04
# Epoch 10/10
# 6064/6064 [==============================] - 29s 5ms/step - loss: 3.0745e-04

# %%
# Evaluate the model on the testing data
loss = model.evaluate(X_test, y_test)

# Make predictions on the testing data
predictions = model.predict(X_test)

# Rescale the original target values
y_test = y_test.reshape(-1, 1)
y_test = scaler.inverse_transform(np.concatenate((np.zeros((y_test.shape[0], 4)), y_test), axis=1))[:, -1]
# y_test_rescaled = scaler.inverse_transform(y_test)

# Rescale the predicted values
predictions = predictions.reshape(-1, 1)
predictions = scaler.inverse_transform(np.concatenate((np.zeros((predictions.shape[0], 4)), predictions), axis=1))[:, -1]
# predictions_rescaled = scaler.inverse_transform(predictions)
# Out:
# 1516/1516 [==============================] - 4s 2ms/step - loss: 1.1889e-04
# 1516/1516 [==============================] - 4s 2ms/step

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score, mean_absolute_error
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, predictions))

# Calculate MAPE
mape = mean_absolute_percentage_error(y_test, predictions)

# Calculate R^2
r2 = r2_score(y_test, predictions)

MAE = mean_absolute_error(y_test, predictions)

print('RMSE:', rmse)
print('MAPE:', mape)
print('R^2:', r2)
print("MAE:", MAE)
# Out:
# RMSE: 0.9496903702119561
# MAPE: 0.006593548770484016
# R^2: 0.5854318282363198
# MAE: 0.3852824245345875

# %%
import matplotlib.pyplot as plt

# Create a range of dates for plotting
dates = test_data['date'].iloc[time_steps:].values

# Plotting the actual prices
plt.plot(dates, y_test, label='Actual')

# Plotting the predicted prices
plt.plot(dates, predictions, label='Predicted')

plt.xlabel('Date')
plt.ylabel('KW')
plt.title('Actual vs. Predicted KW')
plt.legend()
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# # Random Forest

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score, mean_absolute_error

# %%
df = df.sort_values('date')
df = df[['date','separator_speed_rpm_pv', 'mill_dp_mbar_pv', 'cement_type_cpii_bool_pv','gypsum_ton/h_pv_NEW', 'separator_pwr_kw_pv']]
df = df.replace('ERROR', np.nan)  # Replace 'ERROR' with NaN or any appropriate value
df = df.dropna()  # Drop rows with missing values
X = df[['separator_speed_rpm_pv', 'mill_dp_mbar_pv', 'cement_type_cpii_bool_pv','gypsum_ton/h_pv_NEW']]
y = df['separator_pwr_kw_pv']

# Convert the boolean feature to integer (0 or 1)
df['cement_type_cpii_bool_pv'] = df['cement_type_cpii_bool_pv'].astype(float)
# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Specify the number of splits for cross-validation (e.g., 5)
n_splits = 5

# Define the time series cross-validation splitter
tscv = TimeSeriesSplit(n_splits=n_splits)

# %%
# Define the pipeline
pipeline = Pipeline([
    ('scaler', MinMaxScaler()),
    ('rf', RandomForestRegressor())
])

param_grid = {
    'rf__n_estimators': [50, 100, 150],  # Specify the values to be tested
    'rf__max_depth': [None, 5, 10]}  # Example: test None, 5, and 10


# Perform grid search to find the best hyperparameters
grid_search = GridSearchCV(estimator=pipeline, param_grid=param_grid, cv=4, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)


# Get the best hyperparameters and model
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'rf__max_depth': 5, 'rf__n_estimators': 50}

# %%
# Make predictions on the test set using the best model
y_pred = best_model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)

# Calculate the root mean squared error (RMSE)
rmse = mean_squared_error(y_test, y_pred, squared=False)

# Calculate MAPE
mape = mean_absolute_percentage_error(y_test, y_pred)

# Calculate R^2
r2 = r2_score(y_test, y_pred)

MAE = mean_absolute_error(y_test, y_pred)

print('RMSE:', rmse)
print('MAPE:', mape)
print('R^2:', r2)
print('MAE:', MAE)
# Out:
# RMSE: 1.2875514787091336
# MAPE: 0.013742847013407082
# R^2: 0.23784523623367693
# MAE: 0.7971659297353191

# %%
# Plotting the actual and predicted values without the gap

# Create a range of dates for plotting
dates = y_test.index

plt.figure(figsize=(10, 6))  # Set the figure size
plt.plot(dates, y_test, label='Actual')
plt.plot(dates, y_pred, label='Predicted')
plt.xlabel('Date')
plt.ylabel('KW')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
# Plotting the actual and predicted values without the gap

# Create a range of dates for plotting
dates = y_test.index

plt.figure(figsize=(10, 6))  # Set the figure size
plt.plot(dates, y_test, label='Actual')
plt.plot(dates, y_pred, label='Predicted')
plt.xlabel('Date')
plt.ylabel('KW')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # TASK 2

# %%
# print(df['gypsum_ton/h_pv'].isnull().sum())
# print(df['gypsum_ton_h_pv'].isnull().sum())

## Proving that they have nan values in 8 same rows

result1 = df[df['gypsum_ton/h_pv'].isnull() & df['gypsum_ton_h_pv'].isnull()]
result1

# Checking if they are rows that have a non-Nan value in the same rows
result2 = df[df['gypsum_ton/h_pv'].notnull() & df['gypsum_ton_h_pv'].notnull()].all(axis=1)
result2

# Combined Columns
df['gypsum_ton/h_pv_NEW'] = df['gypsum_ton/h_pv'].fillna(df['gypsum_ton_h_pv'])

df['gypsum_ton/h_pv_NEW'].isna().sum()
#Filling the Nan values
df['gypsum_ton/h_pv_NEW'] = pd.to_numeric(df['gypsum_ton/h_pv_NEW'])

df['gypsum_ton/h_pv_NEW'] = df['gypsum_ton/h_pv_NEW'].fillna((df['gypsum_ton/h_pv_NEW'].shift() + df['gypsum_ton/h_pv_NEW'].shift(-1)) / 2)
print(df['gypsum_ton/h_pv_NEW'].isna().sum())


# print(df['total_feed_ton/h_sp'].isnull().sum())
# print(df['total_feed_ton_h_sp'].isnull().sum())

## Proving that they have nan values in 6 same rows

result1 = df[df['total_feed_ton/h_sp'].isnull() & df['total_feed_ton_h_sp'].isnull()]
result1

# Checking if they are rows that have a non-Nan value in the same rows
result2 = df[df['total_feed_ton/h_sp'].notnull() & df['total_feed_ton_h_sp'].notnull()].all(axis=1)
result2

# Combined Columns
df['total_feed_ton/h_sp_NEW'] = df['total_feed_ton/h_sp'].fillna(df['total_feed_ton_h_sp'])

df['total_feed_ton/h_sp_NEW'].isna().sum()
#removing the Nan values
df['total_feed_ton/h_sp_NEW'] = pd.to_numeric(df['total_feed_ton/h_sp_NEW'])

df['total_feed_ton/h_sp_NEW'] = df['total_feed_ton/h_sp_NEW'].fillna((df['total_feed_ton/h_sp_NEW'].shift() + df['total_feed_ton/h_sp_NEW'].shift(-1)) / 2)
print(df['total_feed_ton/h_sp_NEW'].isna().sum())

# print(df['fly_ash_1_ton/h_pv'].isnull().sum())
# print(df['fly_ash_1_ton_h_pv'].isnull().sum())

## Proving that they have nan values in 3 same rows

result1 = df[df['fly_ash_1_ton/h_pv'].isnull() & df['fly_ash_1_ton_h_pv'].isnull()]
result1

# Checking if they are rows that have a non-Nan value in the same rows
result2 = df[df['fly_ash_1_ton/h_pv'].notnull() & df['fly_ash_1_ton_h_pv'].notnull()].all(axis=1)
result2

# Combined Columns
df['fly_ash_1_ton/h_pv_NEW'] = df['fly_ash_1_ton/h_pv'].fillna(df['fly_ash_1_ton_h_pv'])
df['fly_ash_1_ton/h_pv_NEW'].isna().sum()

#removing the Nan values
df['fly_ash_1_ton/h_pv_NEW'] = pd.to_numeric(df['fly_ash_1_ton/h_pv_NEW'])
df['fly_ash_1_ton/h_pv_NEW'] = df['fly_ash_1_ton/h_pv_NEW'].fillna((df['fly_ash_1_ton/h_pv_NEW'].shift() + df['fly_ash_1_ton/h_pv_NEW'].shift(-1)) / 2)
df['fly_ash_1_ton/h_pv_NEW'].isna().sum()

# print(df['fly_ash_1_ton/h_sp'].isnull().sum())
# print(df['fly_ash_1_ton_h_sp'].isnull().sum())

## Proving that they have nan values in 3 same rows

result1 = df[df['fly_ash_1_ton/h_sp'].isnull() & df['fly_ash_1_ton/h_sp'].isnull()]
result1

# Checking if they are rows that have a non-Nan value in the same rows
result2 = df[df['fly_ash_1_ton/h_sp'].notnull() & df['fly_ash_1_ton_h_sp'].notnull()].all(axis=1)
result2

# Combined Columns
df['fly_ash_1_ton/h_sp_NEW'] = df['fly_ash_1_ton/h_sp'].fillna(df['fly_ash_1_ton_h_sp'])
df['fly_ash_1_ton/h_sp_NEW'].isna().sum()

#filling the Nan values
df['fly_ash_1_ton/h_sp_NEW'] = pd.to_numeric(df['fly_ash_1_ton/h_sp_NEW'])
df['fly_ash_1_ton/h_sp_NEW'] = df['fly_ash_1_ton/h_sp_NEW'].fillna((df['fly_ash_1_ton/h_sp_NEW'].shift() + df['fly_ash_1_ton/h_sp_NEW'].shift(-1)) / 2)
df['fly_ash_1_ton/h_sp_NEW'].isna().sum()

# print(df['fly_ash_2_ton/h_pv'].isnull().sum())
# print(df['fly_ash_2_ton_h_pv'].isnull().sum())

## Proving that they have nan values in 3 same rows

result1 = df[df['fly_ash_2_ton/h_pv'].isnull() & df['fly_ash_2_ton_h_pv'].isnull()]
result1

# Checking if they are rows that have a non-Nan value in the same rows
result2 = df[df['fly_ash_2_ton/h_pv'].notnull() & df['fly_ash_2_ton_h_pv'].notnull()].all(axis=1)
result2

# Combined Columns
df['fly_ash_2_ton/h_pv_NEW'] = df['fly_ash_2_ton/h_pv'].fillna(df['fly_ash_2_ton_h_pv'])
df['fly_ash_2_ton/h_pv_NEW'].isna().sum()

#filling the Nan values
df['fly_ash_2_ton/h_pv_NEW'] = pd.to_numeric(df['fly_ash_2_ton/h_pv_NEW'])
df['fly_ash_2_ton/h_pv_NEW'] = df['fly_ash_2_ton/h_pv_NEW'].fillna((df['fly_ash_2_ton/h_pv_NEW'].shift() + df['fly_ash_2_ton/h_pv_NEW'].shift(-1)) / 2)
df['fly_ash_2_ton/h_pv_NEW'].isna().sum()


# print(df['fly_ash_2_ton/h_sp'].isnull().sum())
# print(df['fly_ash_2_ton_h_sp'].isnull().sum())

## Proving that they have nan values in 3 same rows

result1 = df[df['fly_ash_2_ton/h_sp'].isnull() & df['fly_ash_2_ton_h_sp'].isnull()]
result1

# Checking if they are rows that have a non-Nan value in the same rows
result2 = df[df['fly_ash_2_ton/h_sp'].notnull() & df['fly_ash_2_ton_h_sp'].notnull()].all(axis=1)
result2

# Combined Columns
df['fly_ash_2_ton/h_sp_NEW'] = df['fly_ash_2_ton/h_sp'].fillna(df['fly_ash_2_ton_h_sp'])
df['fly_ash_2_ton/h_sp_NEW'].isna().sum()

#filling the Nan values
df['fly_ash_2_ton/h_sp_NEW'] = pd.to_numeric(df['fly_ash_2_ton/h_sp_NEW'])
df['fly_ash_2_ton/h_sp_NEW'] = df['fly_ash_2_ton/h_sp_NEW'].fillna((df['fly_ash_2_ton/h_sp_NEW'].shift() + df['fly_ash_2_ton/h_sp_NEW'].shift(-1)) / 2)
df['fly_ash_2_ton/h_sp_NEW'].isna().sum()

# print(df['mill_injection_water_m3/h_pv'].isnull().sum())
# print(df['mill_injection_water_m3_h_pv'].isnull().sum())

## Proving that they have nan values in 15 same rows

result1 = df[df['mill_injection_water_m3/h_pv'].isnull() & df['mill_injection_water_m3_h_pv'].isnull()]
result1

# Checking if they are rows that have a non-Nan value in the same rows
result2 = df[df['mill_injection_water_m3/h_pv'].notnull() & df['mill_injection_water_m3_h_pv'].notnull()].all(axis=1)
result2

# Combined Columns
df['mill_injection_water_m3/h_pv_NEW'] = df['mill_injection_water_m3/h_pv'].fillna(df['mill_injection_water_m3_h_pv'])
df['mill_injection_water_m3/h_pv_NEW'].isna().sum()

#filling the Nan values
df['mill_injection_water_m3/h_pv_NEW'] = pd.to_numeric(df['mill_injection_water_m3/h_pv_NEW'])

df['mill_injection_water_m3/h_pv_NEW'] = df['mill_injection_water_m3/h_pv_NEW'].fillna((df['mill_injection_water_m3/h_pv_NEW'].shift() + df['mill_injection_water_m3/h_pv_NEW'].shift(-1)) / 2)
print(df['mill_injection_water_m3/h_pv_NEW'].isna().sum())


# print(df['total_feed_ton/h_pv'].isnull().sum())
# print(df['total_feed_ton_h_pv'].isnull().sum())

## Proving that they have nan values in 3 same rows

result1 = df[df['total_feed_ton/h_pv'].isnull() & df['total_feed_ton_h_pv'].isnull()]
result1

# Checking if they are rows that have a non-Nan value in the same rows
result2 = df[df['total_feed_ton/h_pv'].notnull() & df['total_feed_ton_h_pv'].notnull()].all(axis=1)
result2

# Combined Columns
df['total_feed_ton/h_pv_NEW'] = df['total_feed_ton/h_pv'].fillna(df['total_feed_ton_h_pv'])
df['total_feed_ton/h_pv_NEW'].isna().sum()

#removing the Nan values
df['total_feed_ton/h_pv_NEW'] = pd.to_numeric(df['total_feed_ton/h_pv_NEW'])
df['total_feed_ton/h_pv_NEW'] = df['total_feed_ton/h_pv_NEW'].fillna((df['total_feed_ton/h_pv_NEW'].shift() + df['total_feed_ton/h_pv_NEW'].shift(-1)) / 2)
df['total_feed_ton/h_pv_NEW'].isna().sum()
# Out:
# 0
# 0
# 0
# 0

# %%
df2 = df[['date','total_feed_ton/h_pv_NEW','mill_injection_water_m3/h_pv_NEW','fly_ash_2_ton/h_pv_NEW','fly_ash_1_ton/h_pv_NEW','bucket_elv_mtr_pwr_kw_pv','grinding_pressure_bar_pv','separator_speed_rpm_pv','main_fan_speed_rpm_pv','mill_dp_mbar_pv']]
df2
# Out:
#                       date  total_feed_ton/h_pv_NEW  \
# 0      2019-05-10 11:07:30                    85.82
# 1      2019-05-10 11:12:00                    85.50
# 2      2019-05-10 11:24:00                    57.92
# 3      2019-05-10 11:24:30                    57.72
# 4      2019-05-10 11:25:00                    58.01
# ...                    ...                      ...
# 242545 2019-10-05 11:56:00                    65.93
# 242546 2019-10-05 11:56:30                    65.48
# 242547 2019-10-05 11:57:00                    65.68
# 242548 2019-10-05 11:57:30                    65.33
# 242549 2019-10-05 11:58:00                    65.68
#
#         mill_injection_water_m3/h_pv_NEW  fly_ash_2_ton/h_pv_NEW  \
# 0                                   2.69                    0.03
# 1                                   2.69                    0.08
# 2                                   2.45                    0.10
# 3                                   2.46                    0.04
# 4                                   2.46                    0.07
# ...                                  ...                     ...
# 242545                              1.64                    0.08
# 242546                              1.63                    0.09
# 242547                              1.63                    0.06
# 242548                              1.63                    0.11
# 242549                              1.63                    0.03
#
#         fly_ash_1_ton/h_pv_NEW bucket_elv_mtr_pwr_kw_pv  \
# 0                        26.65                     4.88
# 1                        26.34                     4.83
# 2                         0.01                     4.82
# 3                         0.00                     4.85
# 4                         0.01                     4.88
# ...                        ...                      ...
# 242545                    0.02                     4.82
# 242546                    0.06                     4.87
# 242547                    0.01                     4.82
# 242548                    0.01                     4.81
# 242549                    0.03                     4.81
#
#        grinding_pressure_bar_pv  separator_speed_rpm_pv main_fan_speed_rpm_pv  \
# 0                         115.0                  747.14                 928.2
# 1                         116.0                  746.87                 928.2
# 2                         123.0                  717.51                 928.2
# 3                         120.0                  735.89                 928.2
# 4                         118.0                  736.68                 928.2
# ...                         ...                     ...                   ...
# 242545                    112.0                  767.68                   NaN
# 242546                    111.0                  768.10                   NaN
# 242547                    110.0                  769.11                   NaN
# 242548                    108.0                  769.27                   NaN
# 242549                    108.0                  791.40                   NaN
#
#         mill_dp_mbar_pv
# 0                 31.17
# 1                 31.37
# 2                 29.79
# 3                 30.51
# 4                 31.61
# ...                 ...
# 242545            32.83
# 242546            32.91
# 242547            33.65
# 242548            35.03
# 242549            36.42
#
# [242550 rows x 10 columns]

# %%
df2.isna().sum()
# Out:
# date                                     0
# total_feed_ton/h_pv_NEW                  0
# mill_injection_water_m3/h_pv_NEW         0
# fly_ash_2_ton/h_pv_NEW                   0
# fly_ash_1_ton/h_pv_NEW                   0
# bucket_elv_mtr_pwr_kw_pv                 7
# grinding_pressure_bar_pv                 9
# separator_speed_rpm_pv                   0
# main_fan_speed_rpm_pv               180475
# mill_dp_mbar_pv                          0
# dtype: int64

# %%
# df['main_fan_speed_rpm_pv'] = df['main_fan_speed_rpm_pv'].astype(float)
df['main_fan_speed_rpm_pv'] = df['main_fan_speed_rpm_pv'].str.replace(',', '')  # Remove commas
df['main_fan_speed_rpm_pv'] = pd.to_numeric(df['main_fan_speed_rpm_pv'], errors='coerce')
df['main_fan_speed_rpm_pv'].describe()
# Out:
# count    23620.000000
# mean       909.428053
# std        132.517599
# min        357.000000
# 25%        933.337500
# 50%        940.100000
# 75%        952.000000
# max       1056.070000
# Name: main_fan_speed_rpm_pv, dtype: float64

# %%
df['main_fan_speed_rpm_pv'].plot()
# Out:
# <AxesSubplot: >

# %%
df2['bucket_elv_mtr_pwr_kw_pv'] =  pd.to_numeric(df['bucket_elv_mtr_pwr_kw_pv'], errors='coerce')

# %%
df2['bucket_elv_mtr_pwr_kw_pv'] = df2['bucket_elv_mtr_pwr_kw_pv'].fillna((df2['bucket_elv_mtr_pwr_kw_pv'].shift() + df2['bucket_elv_mtr_pwr_kw_pv'].shift(-1)) / 2)
df2['bucket_elv_mtr_pwr_kw_pv'].isna().sum()
# Out:
# 0

# %%
df2['grinding_pressure_bar_pv'] =  pd.to_numeric(df['grinding_pressure_bar_pv'], errors='coerce')
df2['grinding_pressure_bar_pv'] = df2['grinding_pressure_bar_pv'].fillna((df2['grinding_pressure_bar_pv'].shift() + df2['grinding_pressure_bar_pv'].shift(-1)) / 2)
df2['grinding_pressure_bar_pv'].isna().sum()
# Out:
# 0

# %%
df2['grinding_pressure_bar_pv'].plot()
# Out:
# <AxesSubplot: >

# %%
df2.corr()
# Out:
#                                   total_feed_ton/h_pv_NEW  \
# total_feed_ton/h_pv_NEW                          1.000000
# mill_injection_water_m3/h_pv_NEW                 0.683299
# fly_ash_2_ton/h_pv_NEW                           0.381086
# fly_ash_1_ton/h_pv_NEW                           0.431296
# bucket_elv_mtr_pwr_kw_pv                         0.455013
# grinding_pressure_bar_pv                         0.771319
# separator_speed_rpm_pv                           0.116938
# mill_dp_mbar_pv                                  0.497346
#
#                                   mill_injection_water_m3/h_pv_NEW  \
# total_feed_ton/h_pv_NEW                                   0.683299
# mill_injection_water_m3/h_pv_NEW                          1.000000
# fly_ash_2_ton/h_pv_NEW                                    0.289158
# fly_ash_1_ton/h_pv_NEW                                    0.329236
# bucket_elv_mtr_pwr_kw_pv                                  0.300262
# grinding_pressure_bar_pv                                  0.613448
# separator_speed_rpm_pv                                    0.113872
# mill_dp_mbar_pv                                           0.368801
#
#                                   fly_ash_2_ton/h_pv_NEW  \
# total_feed_ton/h_pv_NEW                         0.381086
# mill_injection_water_m3/h_pv_NEW                0.289158
# fly_ash_2_ton/h_pv_NEW                          1.000000
# fly_ash_1_ton/h_pv_NEW                         -0.324369
# bucket_elv_mtr_pwr_kw_pv                        0.082560
# grinding_pressure_bar_pv                        0.142601
# separator_speed_rpm_pv                         -0.102985
# mill_dp_mbar_pv                                 0.035383
#
#                                   fly_ash_1_ton/h_pv_NEW  \
# total_feed_ton/h_pv_NEW                         0.431296
# mill_injection_water_m3/h_pv_NEW                0.329236
# fly_ash_2_ton/h_pv_NEW                         -0.324369
# fly_ash_1_ton/h_pv_NEW                          1.000000
# bucket_elv_mtr_pwr_kw_pv                        0.090519
# grinding_pressure_bar_pv                        0.159622
# separator_speed_rpm_pv                         -0.096733
# mill_dp_mbar_pv                                 0.025437
#
#                                   bucket_elv_mtr_pwr_kw_pv  \
# total_feed_ton/h_pv_NEW                           0.455013
# mill_injection_water_m3/h_pv_NEW                  0.300262
# fly_ash_2_ton/h_pv_NEW                            0.082560
# fly_ash_1_ton/h_pv_NEW                            0.090519
# bucket_elv_mtr_pwr_kw_pv                          1.000000
# grinding_pressure_bar_pv                          0.467317
# separator_speed_rpm_pv                            0.021118
# mill_dp_mbar_pv                                   0.314554
#
#                                   grinding_pressure_bar_pv  \
# total_feed_ton/h_pv_NEW                           0.771319
# mill_injection_water_m3/h_pv_NEW                  0.613448
# fly_ash_2_ton/h_pv_NEW                            0.142601
# fly_ash_1_ton/h_pv_NEW                            0.159622
# bucket_elv_mtr_pwr_kw_pv                          0.467317
# grinding_pressure_bar_pv                          1.000000
# separator_speed_rpm_pv                            0.349876
# mill_dp_mbar_pv                                   0.613915
#
#                                   separator_speed_rpm_pv  mill_dp_mbar_pv
# total_feed_ton/h_pv_NEW                         0.116938         0.497346
# mill_injection_water_m3/h_pv_NEW                0.113872         0.368801
# fly_ash_2_ton/h_pv_NEW                         -0.102985         0.035383
# fly_ash_1_ton/h_pv_NEW                         -0.096733         0.025437
# bucket_elv_mtr_pwr_kw_pv                        0.021118         0.314554
# grinding_pressure_bar_pv                        0.349876         0.613915
# separator_speed_rpm_pv                          1.000000         0.263095
# mill_dp_mbar_pv                                 0.263095         1.000000

# %%
plt.figure(figsize=(20,8))
plt.scatter(df['date'],df['fly_ash_1_ton/h_sp_NEW'])

# %%
plt.figure(figsize=(20,8))
plt.scatter(df['date'],df['fly_ash_1_ton/h_pv_NEW'])
